# %%
#from dataviewer import AutoTabularLoader
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Note, this first section is about removing features that have many missing points. Jump to next section for further analysis of cleaned data to avoid re-running hefty operations.

# %%
#First, we look at NaNs
filepath="datasets/2024_lar.txt"
nrows=12237197
chunk_iterator=pd.read_csv(filepath, delimiter='|', chunksize=50000)
total_nulls=None
for chunk in chunk_iterator:
    chunk_nulls=chunk.isnull().sum()
    #print(chunk_nulls, type(chunk_nulls))
    if total_nulls is None:
        total_nulls=chunk_nulls
    else:
        total_nulls+=chunk_nulls
total_nulls = total_nulls.sort_values(ascending=False)
total_nulls.to_csv('debug_preview.csv')
non_zero_nulls = total_nulls[total_nulls > 0]
null_percentage=(total_nulls / (nrows)) * 100
non_zero_percentage = null_percentage[non_zero_nulls.index]
print(null_percentage)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
bar_width = 0.35
index = np.arange(len(non_zero_percentage))
ax.bar(index, non_zero_percentage, bar_width, label='Percentage Nulls', color='lightblue')
ax.set_xlabel('Columns')
ax.set_ylabel('Percentage of Null Values (%)')
ax.set_title('Percentage of value that are Null for Columns with Null Values')
ax.set_xticks(index)
ax.set_xticklabels(non_zero_percentage.index, rotation=90)
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the analysis of missing data across the dataset, it is clear that many columns with a high percentage of null values, such as secondary ethnicity/race features and certain denial reasons, offer limited value and can likely be dropped. These features lie before the column lender_credits.
#
# On the other hand, columns like property_value, total_loan_costs, and interest_rate, despite having significant missing data, are essential to loan decisions and should not be discarded. These features are key financial indicators and play a crucial role in assessing loan eligibility and risk.

# %%
cols=list(non_zero_percentage.index)
to_discard=cols[0:cols.index('lender_credits')]
output_filepath="datasets/2024_lar_cleaned.csv"
chunksize = 50000
chunk_iterator = pd.read_csv(filepath, delimiter='|', chunksize=chunksize)
first_chunk = True
for chunk in chunk_iterator:
    chunk_cleaned =chunk.drop(columns=to_discard, errors='ignore')  # errors='ignore' prevents error if a column is missing
    chunk_cleaned.to_csv(output_filepath, mode='a', header=first_chunk, index=False)
    first_chunk = False
del chunk
del chunk_cleaned

# %% [markdown]
# Having disgarded many columns, we will work directly off this cleaned csv.

# %%
#Examine data types and variable types of cleaned data
import os
try:
    # Folder where this script is located
    current_dir = os.path.dirname(__file__)
except NameError:
    # __file__ not defined (e.g. interactive mode)
    current_dir = os.getcwd()
output_filepath = os.path.join(current_dir, '..', 'datasets', '2024_lar_cleaned.csv')
output_filepath=os.path.abspath(output_filepath)
print(output_filepath)
chunk_iterator=pd.read_csv(output_filepath, iterator=True)
chunk_peak=chunk_iterator.get_chunk(10000)
print(chunk_peak.info())
chunk_peak.head(15)
# Out:
# /Users/alex/Desktop/TrustWorthyXAILocaltoGlobal/datasets/2024_lar_cleaned.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 73 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   activity_year                             10000 non-null  int64
#  1   lei                                       10000 non-null  object
#  2   derived_msa_md                            10000 non-null  int64
#  3   state_code                                9663 non-null   object
#  4   county_code                               9660 non-null   float64
#  5   census_tract                              9660 non-null   float64
#  6   conforming_loan_limit                     9987 non-null   object
#  7   derived_loan_product_type                 10000 non-null  object
#  8   derived_dwelling_category                 10000 non-null  object
#  9   derived_ethnicity                         10000 non-null  object
#  10  derived_race                              10000 non-null  object
#  11  derived_sex                               10000 non-null  object
#  12  action_taken                              10000 non-null  int64
#  13  purchaser_type                            10000 non-null  int64
#  14  preapproval                               10000 non-null  int64
#  15  loan_type                                 10000 non-null  int64
#  16  loan_purpose                              10000 non-null  int64
#  17  lien_status                               10000 non-null  int64
#  18  reverse_mortgage                          10000 non-null  int64
#  19  open_end_line_of_credit                   10000 non-null  int64
#  20  business_or_commercial_purpose            10000 non-null  int64
#  21  loan_amount                               10000 non-null  int64
#  22  combined_loan_to_value_ratio              8868 non-null   object
#  23  interest_rate                             6719 non-null   object
#  24  rate_spread                               6516 non-null   object
#  25  hoepa_status                              10000 non-null  int64
#  26  total_loan_costs                          3929 non-null   object
#  27  origination_charges                       3929 non-null   object
#  28  discount_points                           1202 non-null   object
#  29  lender_credits                            1756 non-null   object
#  30  loan_term                                 10000 non-null  object
#  31  intro_rate_period                         4915 non-null   object
#  32  negative_amortization                     10000 non-null  int64
#  33  interest_only_payment                     10000 non-null  int64
#  34  balloon_payment                           10000 non-null  int64
#  35  other_nonamortizing_features              10000 non-null  int64
#  36  property_value                            8884 non-null   object
#  37  construction_method                       10000 non-null  int64
#  38  occupancy_type                            10000 non-null  int64
#  39  manufactured_home_secured_property_type   10000 non-null  int64
#  40  manufactured_home_land_property_interest  10000 non-null  int64
#  41  total_units                               10000 non-null  object
#  42  income                                    9722 non-null   float64
#  43  debt_to_income_ratio                      8932 non-null   object
#  44  applicant_credit_score_type               10000 non-null  int64
#  45  co_applicant_credit_score_type            10000 non-null  int64
#  46  applicant_ethnicity_1                     9965 non-null   float64
#  47  co_applicant_ethnicity_1                  9987 non-null   float64
#  48  applicant_ethnicity_observed              10000 non-null  int64
#  49  co_applicant_ethnicity_observed           10000 non-null  int64
#  50  applicant_race_1                          9995 non-null   float64
#  51  co_applicant_race_1                       9996 non-null   float64
#  52  applicant_race_observed                   10000 non-null  int64
#  53  co_applicant_race_observed                10000 non-null  int64
#  54  applicant_sex                             10000 non-null  int64
#  55  co_applicant_sex                          10000 non-null  int64
#  56  applicant_sex_observed                    10000 non-null  int64
#  57  co_applicant_sex_observed                 10000 non-null  int64
#  58  applicant_age                             10000 non-null  object
#  59  co_applicant_age                          10000 non-null  object
#  60  applicant_age_above_62                    9924 non-null   object
#  61  co_applicant_age_above_62                 4626 non-null   object
#  62  submission_of_application                 10000 non-null  int64
#  63  initially_payable_to_institution          10000 non-null  int64
#  64  aus_1                                     10000 non-null  int64
#  65  denial_reason_1                           10000 non-null  int64
#  66  tract_population                          10000 non-null  int64
#  67  tract_minority_population_percent         10000 non-null  float64
#  68  ffiec_msa_md_median_family_income         10000 non-null  int64
#  69  tract_to_msa_income_percentage            10000 non-null  float64
#  70  tract_owner_occupied_units                10000 non-null  int64
#  71  tract_one_to_four_family_homes            10000 non-null  int64
#  72  tract_median_age_of_housing_units         10000 non-null  int64
# dtypes: float64(9), int64(40), object(24)
# memory usage: 5.6+ MB
# None
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3636315728.py:13: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   chunk_peak=chunk_iterator.get_chunk(10000)
#     activity_year                   lei  derived_msa_md state_code  \
# 0            2024  ZF85QS7OXKPBG52R7N18           33340         WI
# 1            2024  ZF85QS7OXKPBG52R7N18           20740         WI
# 2            2024  ZF85QS7OXKPBG52R7N18           39540         WI
# 3            2024  ZF85QS7OXKPBG52R7N18           99999        NaN
# 4            2024  ZF85QS7OXKPBG52R7N18           16984         IL
# 5            2024  ZF85QS7OXKPBG52R7N18           41180         IL
# 6            2024  ZF85QS7OXKPBG52R7N18           36780         WI
# 7            2024  ZF85QS7OXKPBG52R7N18           99999        NaN
# 8            2024  ZF85QS7OXKPBG52R7N18           16984         IL
# 9            2024  ZF85QS7OXKPBG52R7N18           16984         IL
# 10           2024  ZF85QS7OXKPBG52R7N18           16984         IL
# 11           2024  ZF85QS7OXKPBG52R7N18           16984         IL
# 12           2024  ZF85QS7OXKPBG52R7N18           31540         WI
# 13           2024  ZF85QS7OXKPBG52R7N18           43100         WI
# 14           2024  ZF85QS7OXKPBG52R7N18           48140         WI
#
#     county_code  census_tract conforming_loan_limit  \
# 0       55079.0  5.507900e+10                     C
# 1       55035.0  5.503500e+10                     C
# 2       55101.0  5.510100e+10                     C
# 3           NaN           NaN                     C
# 4       17043.0  1.704384e+10                    NC
# 5       17163.0  1.716350e+10                     C
# 6       55139.0  5.513900e+10                     C
# 7           NaN           NaN                     C
# 8       17031.0  1.703183e+10                     C
# 9       17031.0  1.703182e+10                     C
# 10      17031.0  1.703109e+10                     C
# 11      17031.0  1.703108e+10                     C
# 12      55021.0  5.502197e+10                     C
# 13      55117.0  5.511700e+10                     C
# 14      55073.0  5.507300e+10                     C
#
#         derived_loan_product_type             derived_dwelling_category  \
# 0         Conventional:First Lien  Single Family (1-4 Units):Site-Built
# 1   Conventional:Subordinate Lien  Single Family (1-4 Units):Site-Built
# 2         Conventional:First Lien  Single Family (1-4 Units):Site-Built
# 3         Conventional:First Lien  Single Family (1-4 Units):Site-Built
# 4         Conventional:First Lien  Single Family (1-4 Units):Site-Built
# 5   Conventional:Subordinate Lien  Single Family (1-4 Units):Site-Built
# 6         Conventional:First Lien  Single Family (1-4 Units):Site-Built
# 7                  FHA:First Lien  Single Family (1-4 Units):Site-Built
# 8         Conventional:First Lien  Single Family (1-4 Units):Site-Built
# 9         Conventional:First Lien  Single Family (1-4 Units):Site-Built
# 10        Conventional:First Lien  Single Family (1-4 Units):Site-Built
# 11        Conventional:First Lien  Single Family (1-4 Units):Site-Built
# 12  Conventional:Subordinate Lien  Single Family (1-4 Units):Site-Built
# 13  Conventional:Subordinate Lien  Single Family (1-4 Units):Site-Built
# 14  Conventional:Subordinate Lien  Single Family (1-4 Units):Site-Built
#
#           derived_ethnicity  ... initially_payable_to_institution aus_1  \
# 0    Not Hispanic or Latino  ...                                1     1
# 1    Not Hispanic or Latino  ...                                1     6
# 2    Not Hispanic or Latino  ...                                1     1
# 3   Ethnicity Not Available  ...                                1     1
# 4   Ethnicity Not Available  ...                                1     6
# 5    Not Hispanic or Latino  ...                                1     6
# 6    Not Hispanic or Latino  ...                                1     1
# 7    Not Hispanic or Latino  ...                                1     3
# 8    Not Hispanic or Latino  ...                                1     1
# 9        Hispanic or Latino  ...                                1     1
# 10   Not Hispanic or Latino  ...                                1     6
# 11   Not Hispanic or Latino  ...                                1     1
# 12   Not Hispanic or Latino  ...                                1     6
# 13       Hispanic or Latino  ...                                1     6
# 14   Not Hispanic or Latino  ...                                1     6
#
#     denial_reason_1  tract_population  tract_minority_population_percent  \
# 0                10              6158                              82.88
# 1                10              3944                              14.60
# 2                10              6022                               7.24
# 3                10                 0                               0.00
# 4                10              4787                              18.51
# 5                10              6756                               6.90
# 6                10              5045                              10.55
# 7                 3                 0                               0.00
# 8                10              4046                              87.86
# 9                10              4666                              26.49
# 10                1              3585                              19.08
# 11                1              3375                              15.85
# 12               10              5770                               7.24
# 13                1              4344                              25.21
# 14                3              3673                              12.58
#
#     ffiec_msa_md_median_family_income  tract_to_msa_income_percentage  \
# 0                              102100                            61.0
# 1                               99400                           114.0
# 2                               97300                           146.0
# 3                                   0                             0.0
# 4                              109800                           151.0
# 5                              103200                           121.0
# 6                               99100                           119.0
# 7                                   0                             0.0
# 8                              109800                            51.0
# 9                              109800                            75.0
# 10                             109800                           162.0
# 11                             109800                           180.0
# 12                             121200                            99.0
# 13                              86800                            88.0
# 14                              94800                           111.0
#
#     tract_owner_occupied_units  tract_one_to_four_family_homes  \
# 0                         1107                            1771
# 1                         1283                            1626
# 2                         2137                            2566
# 3                            0                               0
# 4                         1478                            1545
# 5                         2226                            2554
# 6                         1510                            1677
# 7                            0                               0
# 8                          961                            1492
# 9                         1097                            1179
# 10                        1225                            1361
# 11                        1212                              68
# 12                        1871                            2681
# 13                        1141                            1736
# 14                        1171                            1541
#
#     tract_median_age_of_housing_units
# 0                                  61
# 1                                  33
# 2                                  29
# 3                                   0
# 4                                  53
# 5                                  40
# 6                                  36
# 7                                   0
# 8                                  53
# 9                                  52
# 10                                 64
# 11                                 53
# 12                                 37
# 13                                 54
# 14                                 56
#
# [15 rows x 73 columns]

# %%
def extract_unique_vals_from_all_columns(file_path, chunk_size=100000, dropna=False):
    unique_vals_dict={}    
    data_types={}
    chunk_iter = pd.read_csv(file_path, chunksize=chunk_size)
    for chunk in chunk_iter:
        for column in chunk.columns:
            if column not in unique_vals_dict:
                unique_vals_dict[column] = set()
                data_types[column]=set()
            if dropna:
                unique_vals = chunk[column].dropna().unique().tolist()
            else:
                unique_vals = chunk[column].unique().tolist()
            unique_vals_dict[column].update(unique_vals)
            inferred_types = {type(v).__name__ for v in unique_vals}
            data_types[column].update(inferred_types)
    sorted_dict = {k: v for k, v in sorted(unique_vals_dict.items(), key=lambda item: len(item[1]), reverse=True)}
    return sorted_dict, data_types
unique_values, data_types = extract_unique_vals_from_all_columns(output_filepath)
# Out:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (5,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (24,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:

# %% [markdown]
# This above piece of code counts the number of unique values across the entire dataframe, mainly used for identifying what data should be considered categorical and what should not. Although a data schema is provided, there might be certain data irregularities that are not necessarily reflected in the schema. For example, the loan_amount is stated to be a continuous variable in the schema. For a dataset with 12M rows, one might expect the number of values of loan_amount to be at least on the same order of magnitude. However, there are only 4003 unique loan_amount values which begs exploration.
#
# Furthermore, values that are meant to be numerical clearly contain strings within them. Careful data-cleaning must be done to identify these edge-cases to prevent mis-representation of information.

# %%
#Now, we will visualise the data types of each column and ensure it matches with the desired schema. 
for col, val in unique_values.items():
    print(f"Column: '{col}' - Number of unique values: {len(val)} - Data Types: {data_types[col]}")
# Out:
# Column: 'total_loan_costs' - Number of unique values: 2149377 - Data Types: {'float', 'str'}
# Column: 'origination_charges' - Number of unique values: 1251267 - Data Types: {'float', 'str'}
# Column: 'discount_points' - Number of unique values: 1047426 - Data Types: {'float', 'str'}
# Column: 'lender_credits' - Number of unique values: 434735 - Data Types: {'float', 'str'}
# Column: 'combined_loan_to_value_ratio' - Number of unique values: 384191 - Data Types: {'float', 'str'}
# Column: 'rate_spread' - Number of unique values: 127502 - Data Types: {'float', 'str'}
# Column: 'census_tract' - Number of unique values: 88109 - Data Types: {'int', 'float', 'str'}
# Column: 'interest_rate' - Number of unique values: 14681 - Data Types: {'float', 'str'}
# Column: 'tract_minority_population_percent' - Number of unique values: 9749 - Data Types: {'float'}
# Column: 'income' - Number of unique values: 9390 - Data Types: {'int', 'float'}
# Column: 'tract_population' - Number of unique values: 8281 - Data Types: {'int'}
# Column: 'property_value' - Number of unique values: 6317 - Data Types: {'float', 'int', 'str'}
# Column: 'lei' - Number of unique values: 4915 - Data Types: {'str'}
# Column: 'loan_amount' - Number of unique values: 4003 - Data Types: {'int'}
# Column: 'tract_one_to_four_family_homes' - Number of unique values: 3516 - Data Types: {'int'}
# Column: 'county_code' - Number of unique values: 3343 - Data Types: {'int', 'float'}
# Column: 'tract_owner_occupied_units' - Number of unique values: 2835 - Data Types: {'int'}
# Column: 'loan_term' - Number of unique values: 1329 - Data Types: {'float', 'int', 'str'}
# Column: 'derived_msa_md' - Number of unique values: 418 - Data Types: {'int'}
# Column: 'intro_rate_period' - Number of unique values: 396 - Data Types: {'float', 'int', 'str'}
# Column: 'tract_to_msa_income_percentage' - Number of unique values: 348 - Data Types: {'float'}
# Column: 'ffiec_msa_md_median_family_income' - Number of unique values: 326 - Data Types: {'int'}
# Column: 'applicant_race_1' - Number of unique values: 100 - Data Types: {'int', 'float'}
# Column: 'applicant_ethnicity_1' - Number of unique values: 93 - Data Types: {'int', 'float'}
# Column: 'co_applicant_race_1' - Number of unique values: 80 - Data Types: {'int', 'float'}
# Column: 'co_applicant_ethnicity_1' - Number of unique values: 78 - Data Types: {'int', 'float'}
# Column: 'tract_median_age_of_housing_units' - Number of unique values: 77 - Data Types: {'int'}
# Column: 'state_code' - Number of unique values: 55 - Data Types: {'float', 'str'}
# Column: 'debt_to_income_ratio' - Number of unique values: 32 - Data Types: {'float', 'str'}
# Column: 'co_applicant_credit_score_type' - Number of unique values: 16 - Data Types: {'int'}
# Column: 'applicant_credit_score_type' - Number of unique values: 15 - Data Types: {'int'}
# Column: 'total_units' - Number of unique values: 13 - Data Types: {'int', 'str'}
# Column: 'purchaser_type' - Number of unique values: 11 - Data Types: {'int'}
# Column: 'co_applicant_age' - Number of unique values: 11 - Data Types: {'int', 'str'}
# Column: 'denial_reason_1' - Number of unique values: 11 - Data Types: {'int'}
# Column: 'derived_race' - Number of unique values: 9 - Data Types: {'str'}
# Column: 'applicant_age' - Number of unique values: 9 - Data Types: {'int', 'str'}
# Column: 'derived_loan_product_type' - Number of unique values: 8 - Data Types: {'str'}
# Column: 'action_taken' - Number of unique values: 8 - Data Types: {'int'}
# Column: 'aus_1' - Number of unique values: 8 - Data Types: {'int'}
# Column: 'loan_purpose' - Number of unique values: 6 - Data Types: {'int'}
# Column: 'manufactured_home_land_property_interest' - Number of unique values: 6 - Data Types: {'int'}
# Column: 'co_applicant_sex' - Number of unique values: 6 - Data Types: {'int'}
# Column: 'co_applicant_age_above_62' - Number of unique values: 6 - Data Types: {'float', 'str'}
# Column: 'derived_ethnicity' - Number of unique values: 5 - Data Types: {'str'}
# Column: 'applicant_sex' - Number of unique values: 5 - Data Types: {'int'}
# Column: 'conforming_loan_limit' - Number of unique values: 4 - Data Types: {'float', 'str'}
# Column: 'derived_dwelling_category' - Number of unique values: 4 - Data Types: {'str'}
# Column: 'derived_sex' - Number of unique values: 4 - Data Types: {'str'}
# Column: 'loan_type' - Number of unique values: 4 - Data Types: {'int'}
# Column: 'manufactured_home_secured_property_type' - Number of unique values: 4 - Data Types: {'int'}
# Column: 'co_applicant_ethnicity_observed' - Number of unique values: 4 - Data Types: {'int'}
# Column: 'co_applicant_race_observed' - Number of unique values: 4 - Data Types: {'int'}
# Column: 'co_applicant_sex_observed' - Number of unique values: 4 - Data Types: {'int'}
# Column: 'applicant_age_above_62' - Number of unique values: 4 - Data Types: {'float', 'str'}
# Column: 'submission_of_application' - Number of unique values: 4 - Data Types: {'int'}
# Column: 'initially_payable_to_institution' - Number of unique values: 4 - Data Types: {'int'}
# Column: 'reverse_mortgage' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'open_end_line_of_credit' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'business_or_commercial_purpose' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'hoepa_status' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'negative_amortization' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'interest_only_payment' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'balloon_payment' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'other_nonamortizing_features' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'occupancy_type' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'applicant_ethnicity_observed' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'applicant_race_observed' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'applicant_sex_observed' - Number of unique values: 3 - Data Types: {'int'}
# Column: 'preapproval' - Number of unique values: 2 - Data Types: {'int'}
# Column: 'lien_status' - Number of unique values: 2 - Data Types: {'int'}
# Column: 'construction_method' - Number of unique values: 2 - Data Types: {'int'}
# Column: 'activity_year' - Number of unique values: 1 - Data Types: {'int'}

# %%
print(unique_values['state_code'])
print(unique_values['debt_to_income_ratio'])
print(unique_values['co_applicant_age_above_62'])
print(unique_values['conforming_loan_limit'])
# Out:
# {'AZ', 'SD', 'WI', 'ME', 'CO', 'OK', 'OR', 'ND', 'IN', 'MD', 'AL', 'AR', nan, 'FL', 'NJ', 'ID', 'NH', 'NY', 'IA', 'TX', 'NE', 'SC', 'HI', 'MS', 'RI', 'MI', 'LA', 'VA', 'OH', 'AK', 'MT', 'MO', 'CT', 'NM', 'VT', 'KS', 'TN', 'CA', 'NV', 'MN', 'MA', 'UT', 'PA', 'WY', 'KY', 'DC', 'IL', 'NC', 'DE', 'GU', 'PR', 'WV', 'WA', 'GA', 'VI'}
# {'50%-60%', '45.0', '<20%', '20%-<30%', nan, '38', '46', '41', 36.0, 38.0, nan, '38.0', '42', 45.0, '>60%', '44', '36', '36.0', '45', '44.0', '37.0', '41.0', '30%-<36%', nan, '43', '47', 'Exempt', '48', '39', '49', '37', '40'}
# {'Yes', nan, nan, nan, 'No', nan}
# {'NC', 'C', 'U', nan}

# %% [markdown]
# It is quite clear that many of the columns having Nans is influencing the data types as NAN is a float, so we will repeat the same function but without the Nans. Furthermore, observe that in debt_to_income ratio, there are two instances of 38, both as an "int" and as a float in the form of 38.0.

# %%
unique_value_without_na, data_types_without_na = extract_unique_vals_from_all_columns(output_filepath, dropna=True)
# Out:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (5,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (24,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/3036544532.py:5: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in chunk_iter:

# %%
print(unique_value_without_na['state_code'])
print(unique_value_without_na['debt_to_income_ratio'])
print(unique_value_without_na['co_applicant_age_above_62'])
print(unique_value_without_na['conforming_loan_limit'])
# Out:
# {'AZ', 'SD', 'WI', 'ME', 'CO', 'OK', 'OR', 'ND', 'IN', 'MD', 'AL', 'AR', 'FL', 'NJ', 'ID', 'NH', 'NY', 'IA', 'TX', 'NE', 'SC', 'HI', 'MS', 'RI', 'MI', 'LA', 'VA', 'OH', 'AK', 'MT', 'MO', 'CT', 'NM', 'VT', 'KS', 'TN', 'CA', 'NV', 'MN', 'MA', 'UT', 'PA', 'WY', 'KY', 'DC', 'IL', 'NC', 'DE', 'GU', 'PR', 'WV', 'WA', 'GA', 'VI'}
# {'50%-60%', '45.0', '<20%', '20%-<30%', '38', '46', '41', 36.0, 38.0, '38.0', '42', 45.0, '>60%', '44', '36', '36.0', '45', '44.0', '37.0', '41.0', '30%-<36%', '43', '47', 'Exempt', '48', '39', '49', '37', '40'}
# {'Yes', 'No'}
# {'NC', 'C', 'U'}

# %% [markdown]
# While dropping Null values simplifies some of the problem, there are still cases where some numbers are entered as strings or floats within the same column, so we will further clean the data by converting values to numeric where possible by column. If they are not, since the data point might be a categorical range like '50%-60%', then we would ignore those.

# %%
def convert_to_numeric(values):
    non_number={}
    converted=[]
    for value in values:
        try:
            converted.append(pd.to_numeric(value, errors='raise'))
        except ValueError:
            # If not convertible, just append the value as is (assuming it's a string).
            if value not in non_number:
                non_number[value]=1
            else:
                non_number[value]+=1
    converted=pd.Series(data=converted, dtype=np.float64)
    return converted, non_number
loan_costs=list(unique_values['total_loan_costs'])
print(f"Number of unique total loan cost values: {len(loan_costs)}")
loan_costs_cleaned, string_vals = convert_to_numeric(loan_costs)
print(loan_costs_cleaned.head(5))
print(f"Number of string values: {sum([string_vals[j] for j in string_vals.keys()])}")
print(string_vals)
print({type(i) for i in loan_costs_cleaned})
loan_numerics=loan_costs_cleaned.dropna()
loan_numerics.describe()
# Out:
# Number of unique total loan cost values: 2149377
# 0       0.00
# 1    6942.76
# 2       2.00
# 3       2.25
# 4       4.00
# dtype: float64
# Number of string values: 1
# {'Exempt': 1}
# {<class 'float'>}
# count    2.149288e+06
# mean     1.325554e+04
# std      4.167224e+06
# min      0.000000e+00
# 25%      5.084517e+03
# 50%      8.841860e+03
# 75%      1.390784e+04
# max      6.109265e+09
# dtype: float64

# %%
Unique_vals_numeric={}
for key, val in unique_value_without_na.items():
    numeric, stringvals=convert_to_numeric(val)
    stringcount=sum([stringvals[j] for j in stringvals.keys()])
    Unique_vals_numeric[key]=[numeric, stringvals, stringcount]

# %%
print("Non numeric features: ")
for k, v in Unique_vals_numeric.items():
    #print(k, v)
    if len(v[0])==0:
        print(k)
print("Testing mixed type columns such as debt_to_income_ratio:")
print(Unique_vals_numeric['debt_to_income_ratio'])
print("What Columns Still have Mixed type?")
mixed=[k for k,v in Unique_vals_numeric.items() if v[2]>0 and len(v[0])>0]
for col in mixed:
    print(col, Unique_vals_numeric[col])
print(f"There are {len(mixed)} features that are still mixed.")
# Out:
# Non numeric features:
# lei
# state_code
# derived_race
# derived_loan_product_type
# derived_ethnicity
# derived_dwelling_category
# derived_sex
# conforming_loan_limit
# applicant_age_above_62
# co_applicant_age_above_62
# Testing mixed type columns such as debt_to_income_ratio:
# [0     45.0
# 1     38.0
# 2     46.0
# 3     41.0
# 4     36.0
# 5     38.0
# 6     38.0
# 7     42.0
# 8     45.0
# 9     44.0
# 10    36.0
# 11    36.0
# 12    45.0
# 13    44.0
# 14    37.0
# 15    41.0
# 16    43.0
# 17    47.0
# 18    48.0
# 19    39.0
# 20    49.0
# 21    37.0
# 22    40.0
# dtype: float64, {'50%-60%': 1, '<20%': 1, '20%-<30%': 1, '>60%': 1, '30%-<36%': 1, 'Exempt': 1}, 6]
# What Columns Still have Mixed type?
# total_loan_costs [0              0.00
# 1           6942.76
# 2              2.00
# 3              2.25
# 4              4.00
#              ...
# 2149283    19960.71
# 2149284     3592.63
# 2149285     8845.06
# 2149286     7860.21
# 2149287    13750.08
# Length: 2149288, dtype: float64, {'Exempt': 1}, 1]
# origination_charges [0              0.00
# 1              0.50
# 2              0.75
# 3              3.50
# 4              1.00
#              ...
# 1251173     3770.60
# 1251174    12880.00
# 1251175     8954.17
# 1251176     3592.63
# 1251177     4034.87
# Length: 1251178, dtype: float64, {'Exempt': 1}, 1]
# discount_points [0              0.50
# 1              1.00
# 2              2.75
# 3              3.50
# 4              4.75
#              ...
# 1047332     3770.60
# 1047333    12880.00
# 1047334     3177.65
# 1047335     4034.87
# 1047336     9421.65
# Length: 1047337, dtype: float64, {'Exempt': 1}, 1]
# lender_credits [0             0.25
# 1             0.50
# 2             1.75
# 3             3.75
# 4             4.25
#             ...
# 434641     7708.68
# 434642      166.20
# 434643    12880.00
# 434644      778.18
# 434645     1070.15
# Length: 434646, dtype: float64, {'Exempt': 1}, 1]
# combined_loan_to_value_ratio [0          0.500
# 1          1.500
# 2          2.000
# 3          3.500
# 4          3.000
#            ...
# 384097    77.752
# 384098    77.252
# 384099    63.499
# 384100    77.002
# 384101    81.615
# Length: 384102, dtype: float64, {'Exempt': 1}, 1]
# rate_spread [0         0.7500
# 1         1.0000
# 2         1.5000
# 3         0.5000
# 4         1.6250
#            ...
# 127408    2.3360
# 127409   -4.7500
# 127410   -3.3827
# 127411   -2.2500
# 127412   -1.1875
# Length: 127413, dtype: float64, {'Exempt': 1}, 1]
# census_tract [0        3.607101e+10
# 1        2.714501e+10
# 2        2.714501e+10
# 3        3.900301e+10
# 4        2.205103e+10
#              ...
# 87982    6.037701e+09
# 87983    3.501300e+10
# 87984    3.501300e+10
# 87985    3.501300e+10
# 87986    1.703700e+10
# Length: 87987, dtype: float64, {'na': 1}, 1]
# interest_rate [0         6.5900
# 1         0.0000
# 2         2.8750
# 3         3.6250
# 4         4.8750
#           ...
# 14589     7.9127
# 14590     7.2760
# 14591    11.2400
# 14592     6.2990
# 14593     6.1800
# Length: 14594, dtype: float64, {'Exempt': 1}, 1]
# property_value [0       1.620050e+08
# 1       1.864500e+07
# 2       5.960500e+07
# 3       1.515000e+06
# 4       1.000050e+08
#             ...
# 6224    1.332500e+07
# 6225    5.505000e+06
# 6226    2.598500e+07
# 6227    1.835000e+06
# 6228    2.147484e+09
# Length: 6229, dtype: float64, {'Exempt': 1}, 1]
# loan_term [0         1.0
# 1         2.0
# 2         3.0
# 3         4.0
# 4         5.0
#         ...
# 1265    227.0
# 1266      4.0
# 1267     89.0
# 1268    107.0
# 1269    280.0
# Length: 1270, dtype: float64, {'Exempt': 1}, 1]
# intro_rate_period [0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#        ...
# 302     91.0
# 303     69.0
# 304     64.0
# 305    136.0
# 306     66.0
# Length: 307, dtype: float64, {'Exempt': 1}, 1]
# debt_to_income_ratio [0     45.0
# 1     38.0
# 2     46.0
# 3     41.0
# 4     36.0
# 5     38.0
# 6     38.0
# 7     42.0
# 8     45.0
# 9     44.0
# 10    36.0
# 11    36.0
# 12    45.0
# 13    44.0
# 14    37.0
# 15    41.0
# 16    43.0
# 17    47.0
# 18    48.0
# 19    39.0
# 20    49.0
# 21    37.0
# 22    40.0
# dtype: float64, {'50%-60%': 1, '<20%': 1, '20%-<30%': 1, '>60%': 1, '30%-<36%': 1, 'Exempt': 1}, 6]
# total_units [0    1.0
# 1    2.0
# 2    4.0
# 3    3.0
# 4    3.0
# 5    4.0
# 6    1.0
# 7    2.0
# dtype: float64, {'50-99': 1, '>149': 1, '100-149': 1, '25-49': 1, '5-24': 1}, 5]
# co_applicant_age [0    9999.0
# 1    8888.0
# 2    9999.0
# 3    8888.0
# dtype: float64, {'45-54': 1, '65-74': 1, '25-34': 1, '>74': 1, '35-44': 1, '55-64': 1, '<25': 1}, 7]
# applicant_age [0    8888.0
# 1    8888.0
# dtype: float64, {'45-54': 1, '65-74': 1, '25-34': 1, '35-44': 1, '>74': 1, '55-64': 1, '<25': 1}, 7]
# There are 15 features that are still mixed.

# %% [markdown]
# There are 15 features that have mixed attributes even after active filtering. A manual inspection reveals that these string attributes are mainly caused by strings of the form "Exempt" or in a numerical range. The rest of the features that are numerical can either be categorical features or continuous features. Regarding the identified non-numeric features of "lei
# state_code
# derived_race
# derived_loan_product_type
# derived_ethnicity
# derived_dwelling_category
# derived_sex
# conforming_loan_limit
# applicant_age_above_62
# co_applicant_age_above_62"
# These are mainly categorical or boolean.
# With this data-cleaning and quality check complete, it is sufficient to know which of the key features are ready for vizualisation.
#
# First, we will begin with the action_taken label, which is the result of the loan decision, and is our output variable. But before that, we will define a utility function that samples from chunked dataset

# %%
def sample_from_chunked(columns, df, sample_size, seed=44, nrows=None, dropna=True):
    """
    Assumes that there is enough representative data left after droppning Nans
    """
    if isinstance(columns, str):
        columns=[columns]
    if isinstance(df, pd.DataFrame):
        valid_df=df.dropna(subset=columns)
        assert len(valid_df)>sample_size, "Length of dataframe cannot be less than sample size"
        sampled_df = valid_df.sample(n=sample_size, random_state=seed)
        sampled_df=sampled_df[columns]
        return sampled_df
    else:
        assert nrows is not None, "Please provide nrows for a chunked dataset"
        assert nrows>sample_size, "Length of dataframe cannot be less than sample size"
        ratio=sample_size/nrows
        sampled=[]
        for chunk in df:
            chunksamplecount=int((ratio*len(chunk))//1)
            valid_chunk = chunk.dropna(subset=columns) if dropna else chunk
            sampled.append(valid_chunk.sample(n=chunksamplecount, random_state=seed)[columns])
        sampled_df=pd.concat(sampled, axis=0)
        return sampled_df

# %%
def categorical_to_chart(column_name, df, codemap=None, top_n=15):
    """
    Plots a pie chart for a categorical column with a clean legend. Also assumes data has no Nans
    Args:
        column_name (str): Name of the column to visualize.
        top_n (int): Show top N categories by frequency.
    """
    value_counts = df[column_name].value_counts()
    top_n=min(top_n, len(value_counts))
    value_counts=value_counts.head(top_n)
    labels = value_counts.index.tolist()
    sizes = value_counts.values
    total = sizes.sum()
    if codemap:
        labels = [str(l)+": "+str(codemap.get(l, l)) for l in labels]
    legend_labels = [f"{l}: {s/total*100:.1f}%" for l, s in zip(labels, sizes)]

    fig, ax = plt.subplots(figsize=(8, 8))
    wedges, texts = ax.pie(
        sizes,
        startangle=90,
        labels=None,
        counterclock=False
    )

    ax.legend(
        wedges,
        legend_labels,
        title=f"{column_name} distribution",
        loc="center left",
        bbox_to_anchor=(1, 0.5),
        fontsize=10
    )
    
    ax.set_title(f"Distribution of {column_name}", fontsize=14)
    plt.tight_layout()
    plt.show()
ACTION_TAKEN_LABELS = {
    1: "Loan originated",
    2: "Application approved but not accepted",
    3: "Application denied",
    4: "Application withdrawn by applicant",
    5: "File closed for incompleteness",
    6: "Purchased loan",
    7: "Preapproval request denied",
    8: "Preapproval request approved but not accepted"
}
chunk_iterator=pd.read_csv(output_filepath, chunksize=500000)
action_taken_sample=sample_from_chunked(columns=['action_taken'], df=chunk_iterator, nrows=12237197, sample_size=200000)
action_taken_sample.head(5)
categorical_to_chart("action_taken", action_taken_sample, codemap=ACTION_TAKEN_LABELS)
# Out:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (5,22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2775216313.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:

# %%
#As we can see, the following is clearly a categorical Feature, where 8888 represents NAN. Copying categories from schema,
print(Unique_vals_numeric['denial_reason_1'])
denial_reason_code = {
    1: "Debt-to-income ratio",
    2: "Employment history",
    3: "Credit history",
    4: "Collateral",
    5: "Insufficient cash (downpayment, closing costs)",
    6: "Unverifiable information",
    7: "Credit application incomplete",
    8: "Mortgage insurance denied",
    9: "Other",
    10: "Not applicable",
    1111: "NaN"  # Special case for NaN values, often used as a placeholder for missing data
}
chunk_iterator=pd.read_csv(output_filepath, chunksize=500000)
denial_reason_sample=sample_from_chunked(columns=['denial_reason_1'], df=chunk_iterator, nrows=12237197, sample_size=200000)
denial_reason_sample.head(5)
categorical_to_chart(column_name='denial_reason_1', df=denial_reason_sample, codemap=denial_reason_code)

# %%
def jitterplot(columns, data, nrows=None, jitter=0.05, title="Jitter Plot", xlabel='Column(s)', ylabel="value", sample_size=None):
    """
    Assumes data has no Nans
     Parameters:
    - data: A DataFrame or an iterator of chunks from pd.read_csv (TextFileReader)
    - columns: Single column name (str) or list of column names (list of str)
    - jitter_strength: The amount of random displacement for jitter (default is 0.05)
    - title: The title of the plot
    - sample_size: The number of samples to take from each chunk (default is None to plot all data)
    """
    if isinstance(columns, str):
        columns = [columns]
     # Create a figure with subplots (one for each column)
    n = len(columns)
    plt.figure(figsize=(10, 6 * n)) 
    sampled_data = {col: [] for col in columns}
    # If the data is already a DataFrame
    if isinstance(data, pd.DataFrame):
        for i, col in enumerate(columns):
            jittered_x = np.random.normal(0, jitter, size=len(data))  # Jitter based on row number
            jittered_y = data[col]
            plt.subplot(n, 1, i + 1)  # Create a new subplot for each column
            plt.scatter(jittered_x, jittered_y, alpha=0.4, label=col, color='blue', marker="o")
            plt.title(f"{title} - {col}", fontsize=16)
            plt.xlabel(xlabel, fontsize=12)
            plt.ylabel(ylabel, fontsize=12)
            plt.grid(True, linestyle='--', alpha=0.5)
            plt.tight_layout()

    # If the data is a chunked iterator (TextFileReader)
    elif isinstance(data, pd.io.parsers.TextFileReader):
        assert nrows is not None, "Please pass in an nrows parameter if data is an iterator"
        if sample_size is None:
            full_data = pd.concat((chunk[columns] for chunk in data), ignore_index=True)
            for i, col in enumerate(columns):
                jittered_x = np.random.normal(0, jitter, size=len(full_data))  # Jitter based on row number
                jittered_y = full_data[col]
                plt.subplot(n, 1, i + 1)  # Create a new subplot for each column
                plt.scatter(jittered_x, jittered_y, alpha=0.4, label=col, color='blue', marker="o")
                plt.title(f"{title} - {col}", fontsize=16)
                plt.xlabel(f"Column: {col}", fontsize=12)
                plt.ylabel(ylabel, fontsize=12)
                plt.grid(True, linestyle='--', alpha=0.5)
                plt.tight_layout()

        else:
            # Otherwise, sample from each chunk and store the jittered data
            ratio=sample_size/nrows
            for chunk in data:
                # Randomly sample from each chunk
                chunk_sample_size=int((ratio*len(chunk))//1)
                sampled_chunk = chunk.sample(n=chunk_sample_size, random_state=42)
                for col in columns:
                    values = sampled_chunk[col]
                    jittered_x = np.random.normal(0, jitter, size=len(values))  # Jitter based on row number
                    sampled_data[col].extend(zip(jittered_x, values))  # Store as (jittered_x, value)
            
            # Plot the jittered data for each column
            for i, col in enumerate(columns):
                jittered_x, jittered_y = zip(*sampled_data[col])  # Unzip the jittered data
                plt.subplot(n, 1, i + 1)  # Create a new subplot for each column
                plt.scatter(jittered_x, jittered_y, alpha=0.7, label=col, color='blue', marker="o")
                plt.title(f"{title} - {col}", fontsize=16)
                plt.xlabel(xlabel, fontsize=12)
                plt.ylabel(ylabel, fontsize=12)
                plt.grid(True, linestyle='--', alpha=0.5)
                plt.tight_layout()

    plt.show()

# %%
#Examine the values of numeric features
print(Unique_vals_numeric['ffiec_msa_md_median_family_income'])
print(Unique_vals_numeric['loan_amount'])
print(Unique_vals_numeric['property_value'])
print(Unique_vals_numeric['income'])

# %%
chunk_iterator=pd.read_csv(output_filepath, chunksize=500000)
cols=['ffiec_msa_md_median_family_income', 'loan_amount', 'property_value', 'income']
sample=sample_from_chunked(columns=cols, df=chunk_iterator, nrows=12237197, sample_size=200000)
print(sample.head(5))
jitterplot(columns='property_value', data=sample[sample['property_value'] != "Exempt"], jitter=0.000001)
jitterplot(columns=['loan_amount', 'ffiec_msa_md_median_family_income', 'income'], data=sample, jitter=0.0001)

# %%
chunk_iterator=pd.read_csv(output_filepath, chunksize=1)
t=next(chunk_iterator)
columns=t.columns.tolist()
print(columns)
chunk_iterator=pd.read_csv(output_filepath, chunksize=100000)
test_dataset=sample_from_chunked(columns=columns, df=chunk_iterator, sample_size=500000, seed=78, nrows=12237197, dropna=False)
test_dataset.to_csv("500ktest_dataset_lar.csv")
# Out:
# ['activity_year', 'lei', 'derived_msa_md', 'state_code', 'county_code', 'census_tract', 'conforming_loan_limit', 'derived_loan_product_type', 'derived_dwelling_category', 'derived_ethnicity', 'derived_race', 'derived_sex', 'action_taken', 'purchaser_type', 'preapproval', 'loan_type', 'loan_purpose', 'lien_status', 'reverse_mortgage', 'open_end_line_of_credit', 'business_or_commercial_purpose', 'loan_amount', 'combined_loan_to_value_ratio', 'interest_rate', 'rate_spread', 'hoepa_status', 'total_loan_costs', 'origination_charges', 'discount_points', 'lender_credits', 'loan_term', 'intro_rate_period', 'negative_amortization', 'interest_only_payment', 'balloon_payment', 'other_nonamortizing_features', 'property_value', 'construction_method', 'occupancy_type', 'manufactured_home_secured_property_type', 'manufactured_home_land_property_interest', 'total_units', 'income', 'debt_to_income_ratio', 'applicant_credit_score_type', 'co_applicant_credit_score_type', 'applicant_ethnicity_1', 'co_applicant_ethnicity_1', 'applicant_ethnicity_observed', 'co_applicant_ethnicity_observed', 'applicant_race_1', 'co_applicant_race_1', 'applicant_race_observed', 'co_applicant_race_observed', 'applicant_sex', 'co_applicant_sex', 'applicant_sex_observed', 'co_applicant_sex_observed', 'applicant_age', 'co_applicant_age', 'applicant_age_above_62', 'co_applicant_age_above_62', 'submission_of_application', 'initially_payable_to_institution', 'aus_1', 'denial_reason_1', 'tract_population', 'tract_minority_population_percent', 'ffiec_msa_md_median_family_income', 'tract_to_msa_income_percentage', 'tract_owner_occupied_units', 'tract_one_to_four_family_homes', 'tract_median_age_of_housing_units']
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (5,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (24,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41,43,58,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (22,23,24,26,27,28,29,30,31,36,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
# /var/folders/b0/ymr48tf963d9_3y2jfmn5wfw0000gn/T/ipykernel_29656/2286851209.py:18: DtypeWarning: Columns (41) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df:
